# %%
import numpy as np
import pandas as pd

import plotly.express as px
from plotly.subplots import make_subplots

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import IncrementalPCA

# %%
SENSOR_TAGS = ("PI", "PT")
sensor_cols = [c for c in df.columns if any(tag in c for tag in SENSOR_TAGS)]

X = df[sensor_cols].values
n_samples, n_features = X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 SENSOR_TAGS = ("PI", "PT")
# ----> 2 sensor_cols = [c for c in df.columns if any(tag in c for tag in SENSOR_TAGS)]
#       4 X = df[sensor_cols].values
#       5 n_samples, n_features = X.shape
#
# NameError: name 'df' is not defined
